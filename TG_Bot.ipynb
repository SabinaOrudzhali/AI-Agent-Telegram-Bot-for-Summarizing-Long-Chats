# %%
# %%writefile .env
# TG_TOKEN=8832835814:AAEvM5AY2qMFIQFeCWWgkhMVYcVRKeZocXk
# GIGACHAT_AUTH_KEY=MDE5ZWEyYTctZjU1NS03OWMyLWI4NDgtOTg3YzAxOWJiODg0Ojg4ZDhkNDU2LWJjMmEtNGNhZi1hODBiLTVkZGRjMjdiNjk3Mw==
# GIGACHAT_SCOPE=GIGACHAT_API_PERS
# Out:
# Writing .env

# %%
# !pip install python-telegram-bot==21.6 gigachat==0.1.36 python-dotenv==1.0.1
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 652.1/652.1 kB 43.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 5.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: python-dotenv
#     Found existing installation: python-dotenv 1.2.2
#     Uninstalling python-dotenv-1.2.2:
#       Successfully uninstalled python-dotenv-1.2.2
# ...

# %%
# !python bot.py
# Out:
# INFO:summary_bot:Bot started
# INFO:httpx:HTTP Request: POST https://api.telegram.org/bot8832835814:AAEvM5AY2qMFIQFeCWWgkhMVYcVRKeZocXk/getMe "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.telegram.org/bot8832835814:AAEvM5AY2qMFIQFeCWWgkhMVYcVRKeZocXk/deleteWebhook "HTTP/1.1 200 OK"
# INFO:telegram.ext.Application:Application started
# INFO:httpx:HTTP Request: POST https://api.telegram.org/bot8832835814:AAEvM5AY2qMFIQFeCWWgkhMVYcVRKeZocXk/getUpdates "HTTP/1.1 200 OK"
